# %%
from datetime import datetime, timedelta

# %% [markdown]
# Задание 1

# %%
#The Moscow Times — Wednesday, October 2, 2002
datetime.strptime('Wednesday, October 2, 2002', '%A, %B %d, %Y')
# Out:
# datetime.datetime(2002, 10, 2, 0, 0)

# %%
#The Guardian — Friday, 11.10.13
datetime.strptime('Friday, 11.10.13', '%A, %d.%m.%y')
# Out:
# datetime.datetime(2013, 10, 11, 0, 0)

# %%
#Daily News — Thursday, 18 August 1977 - '%A, %d %B %y'
datetime.strptime('Thursday, 18 August 1977', '%A, %d %B %Y')
# Out:
# datetime.datetime(1977, 8, 18, 0, 0)

# %% [markdown]
# Задание 2

# %%
stream = ['2018-04-02', '2018-02-29', '2018-19-02']
for i in stream:
    try:
        datetime.strptime(i, '%Y-%m-%d')  # формат: ГГГГ-ММ-ДД
        print(f'{i} - True')
    except ValueError:
        print(f'{i} - False')
# Out:
# 2018-04-02 - True
# 2018-02-29 - False
# 2018-19-02 - False

# %% [markdown]
# Задание 3

# %%
def date_range(start_date, end_date):
    try:
        start = datetime.strptime(start_date, '%Y-%m-%d')
        end = datetime.strptime(end_date, '%Y-%m-%d')
    except ValueError:
        return []
    if start > end:
        return []
    dates = []
    current = start
    while current <= end:
        dates.append(current.strftime('%Y-%m-%d'))
        current += timedelta(days=1)
    return dates

# %%
date_range('2025-02-14', '2025-03-05')
# Out:
# ['2025-02-14',
#  '2025-02-15',
#  '2025-02-16',
#  '2025-02-17',
#  '2025-02-18',
#  '2025-02-19',
#  '2025-02-20',
#  '2025-02-21',
#  '2025-02-22',
#  '2025-02-23',
#  '2025-02-24',
#  '2025-02-25',
#  '2025-02-26',
#  '2025-02-27',
#  '2025-02-28',
#  '2025-03-01',
#  '2025-03-02',
#  '2025-03-03',
#  '2025-03-04',
#  '2025-03-05']

# %% [markdown]
# Задание 4
# Ошибка list index out of range означает, что происходит обращение к элементу списка по индексу, которого не существует. В первом случае код срабатывает, потому что при первом вызове функции удаляется последний элемент A102 и список становиться ['A100', 'A101'], затем возвращается элемент с индексом DEFAULT_USER_COUNT-2 = 1 - 'A101' Во втором случае из списка ['A100', 'A101'] удаляется последний элемент и список остается с одним элементом, индекс которого [0] и соответственно при попытке обратится к индексу [1] выходит ошибка, т.к. в списке элемент с индексом [1] отсутствует.
#
# Буду рад любым замечаниям!
